# %%
import xarray as xr
import pysumma as ps
import geopandas as gpd
import cartopy.crs as ccrs
import pysumma.plotting as psp
import matplotlib.pyplot as plt
from utils.read_files import read_from_control, make_default_path
from pathlib import Path

# %%
# Store the name of the 'active' file in a variable
basin = "EastRiver"
controlFile = f'control_{basin}.txt'

# %%
# Forcing file list path & name
filemanager_path = read_from_control(controlFile,'settings_summa_path')
filemanager_name = read_from_control(controlFile,'settings_summa_filemanager')


# Forcing file list path & name
filemanager_path = read_from_control(controlFile,'settings_summa_path')
filemanager_name = read_from_control(controlFile,'settings_summa_filemanager')
# Specify default path if needed
if filemanager_path == 'default':
    filemanager_path = make_default_path('settings/SUMMA', controlFile) # outputs a Path()
else:
    filemanager_path = Path(filemanager_path) # make sure a user-specified path is a Path()


# Make the folder if it doesn't exist
filemanager_path.mkdir(parents=True, exist_ok=True)

# %%
# Update this path to the location of your file manager
file_manager = str(filemanager_path / filemanager_name)
summa_exe = 'summa.exe'

s = ps.Distributed(summa_exe, file_manager, chunk_size=2)
s.simulations.keys()
# Out:
# dict_keys(['g1-1'])

# %%
# %%time
s.run()
print(s.summary())
# Out:
# {'Success': [], 'Error': ['g1-1', 'Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG\nSTOP 1\n', "file_suffix is 'g1-1'.\nfile_master is '/storage/dlhogan/summa_modeling_data/domain_EastRiver/settings/SUMMA/.pysumma/g1-1/fileManager.txt'.\n GRU-Parallelization run activated. 1 GRUs are selected for simulation.\n   1 controlVersion: SUMMA_FILE_MANAGER_V3.0.0\n   2 simStartTime: 2021-10-01 00:00\n   3 simEndTime: 2023-09-30 23:00\n   4 tmZoneInfo: utcTime\n   5 outFilePrefix: run1\n   6 settingsPath: /storage/dlhogan/summa_modeling_data/domain_EastRiver/settings/SUMMA/.pysumma/g1-1/\n   7 forcingPath: /storage/dlhogan/summa_modeling_data/domain_EastRiver/forcing/4_SUMMA_input/\n   8 outputPath: /storage/dlhogan/summa_modeling_data/domain_EastRiver/simulations/run1/SUMMA/\n   9 initConditionFile: coldState.nc\n  10 attributeFile: attributes.nc\n  11 trialParamFile: trialParams.nc\n  12 forcingListFile: forcingFileList.txt\n  13 decisionsFile: modelDecisions.txt\n  14 outputControlFile: outputControl.txt\n  15 globalHruParamFile: localParamInfo.txt\n  16 globalGruParamFile: basinParamInfo.txt\n  17 vegTableFile: TBL_VEGPARM.TBL\n  18 soilTableFile: TBL_SOILPARM.TBL\n  19 generalTableFile: TBL_GENPARM.TBL\n  20 noahmpTableFile: TBL_MPTABLE.TBL\n id variable requested in outputControl, will be skipped: variable=hruId\ndecisions file =  /storage/dlhogan/summa_modeling_data/domain_EastRiver/settings/SUMMA/.pysumma/g1-1/modelDecisions.txt\n   1 soilCatTbl: ROSETTA\n   2 vegeParTbl: MODIFIED_IGBP_MODIS_NOAH\n   3 soilStress: NoahType\n   4 stomResist: BallBerry\n   5 num_method: itertive\n   6 fDerivMeth: analytic\n   7 LAI_method: monTable\n   8 f_Richards: mixdform\n   9 groundwatr: bigBuckt\n  10 hc_profile: pow_prof\n  11 bcUpprTdyn: nrg_flux\n  12 bcLowrTdyn: zeroFlux\n  13 bcUpprSoiH: liq_flux\n  14 bcLowrSoiH: drainage\n  15 veg_traits: CM_QJRMS1988\n  16 rootProfil: powerLaw\n  17 canopyEmis: difTrans\n  18 snowIncept: stickySnow\n  19 windPrfile: logBelowCanopy\n  20 astability: louisinv\n  21 canopySrad: BeersLaw\n  22 alb_method: varDecay\n  23 compaction: anderson\n  24 snowLayers: CLM_2010\n  25 thCondSnow: jrdn1991\n  26 thCondSoil: funcSoilWet\n  27 spatial_gw: localColumn\n  28 subRouting: timeDlay\nstartTime: iyyy, im, id, ih, imin = 2021 10  1  0  0\nfinshTime: iyyy, im, id, ih, imin = 2023  9 30 23  0\nnumber of time steps =         731\n \nINFO: aspect not found in the input attribute file, continuing ...\n\nSkipping over LUTYPE = USGS\nSkipping over SLTYPE = STAS\nSkipping over SLTYPE = STAS-RUC\n WARNING: routingRunoffFuture is not in the initial conditions file ... using zeros\n Created output file: /storage/dlhogan/summa_modeling_data/domain_EastRiver/simulations/run1/SUMMA/run1_g1-1_G1-1_timestep.nc\n2021 10  2  0  0\n2021 10  3  0  0\n2021 10  4  0  0\n2021 10  5  0  0\n2021 10  6  0  0\n2021 10  7  0  0\n2021 10  8  0  0\n2021 10  9  0  0\n2021 10 10  0  0\n2021 10 11  0  0\n2021 10 12  0  0\n2021 10 13  0  0\n2021 10 14  0  0\n2021 10 15  0  0\n2021 10 16  0  0\n2021 10 17  0  0\n2021 10 18  0  0\n2021 10 19  0  0\n2021 10 20  0  0\n2021 10 21  0  0\n2021 10 22  0  0\n2021 10 23  0  0\n2021 10 24  0  0\n2021 10 25  0  0\n2021 10 26  0  0\n2021 10 27  0  0\n2021 10 28  0  0\n2021 10 29  0  0\n2021 10 30  0  0\n2021 10 31  0  0\n2021 11  1  0  0\n2021 11  2  0  0\n2021 11  3  0  0\n2021 11  4  0  0\n2021 11  5  0  0\n2021 11  6  0  0\n2021 11  7  0  0\n2021 11  8  0  0\n2021 11  9  0  0\n2021 11 10  0  0\n2021 11 11  0  0\n2021 11 12  0  0\n2021 11 13  0  0\n2021 11 14  0  0\n2021 11 15  0  0\n2021 11 16  0  0\n2021 11 17  0  0\n2021 11 18  0  0\n2021 11 19  0  0\n2021 11 20  0  0\n2021 11 21  0  0\n2021 11 22  0  0\n2021 11 23  0  0\n2021 11 24  0  0\n2021 11 25  0  0\n2021 11 26  0  0\n2021 11 27  0  0\n2021 11 28  0  0\n2021 11 29  0  0\n2021 11 30  0  0\n2021 12  1  0  0\n2021 12  2  0  0\n2021 12  3  0  0\n2021 12  4  0  0\n2021 12  5  0  0\n2021 12  6  0  0\n2021 12  7  0  0\ ...
# CPU times: user 379 ms, sys: 89.7 ms, total: 469 ms
# Wall time: 8.72 s

# %%
print(s.summary()['Error'][2])
# Out:
# file_suffix is 'g1-1'.
# file_master is '/storage/dlhogan/summa_modeling_data/domain_EastRiver/settings/SUMMA/.pysumma/g1-1/fileManager.txt'.
#  GRU-Parallelization run activated. 1 GRUs are selected for simulation.
#    1 controlVersion: SUMMA_FILE_MANAGER_V3.0.0
#    2 simStartTime: 2021-10-01 00:00
#    3 simEndTime: 2023-09-30 23:00
#    4 tmZoneInfo: utcTime
#    5 outFilePrefix: run1
#    6 settingsPath: /storage/dlhogan/summa_modeling_data/domain_EastRiver/settings/SUMMA/.pysumma/g1-1/
#    7 forcingPath: /storage/dlhogan/summa_modeling_data/domain_EastRiver/forcing/4_SUMMA_input/
#    8 outputPath: /storage/dlhogan/summa_modeling_data/domain_EastRiver/simulations/run1/SUMMA/
#    9 initConditionFile: coldState.nc
#   10 attributeFile: attributes.nc
#   11 trialParamFile: trialParams.nc
#   12 forcingListFile: forcingFileList.txt
#   13 decisionsFile: modelDecisions.txt
#   14 outputControlFile: outputControl.txt
#   15 globalHruParamFile: localParamInfo.txt
#   16 globalGruParamFile: basinParamInfo.txt
#   17 vegTableFile: TBL_VEGPARM.TBL
#   18 soilTableFile: TBL_SOILPARM.TBL
#   19 generalTableFile: TBL_GENPARM.TBL
#   20 noahmpTableFile: TBL_MPTABLE.TBL
#  id variable requested in outputControl, will be skipped: variable=hruId
# decisions file =  /storage/dlhogan/summa_modeling_data/domain_EastRiver/settings/SUMMA/.pysumma/g1-1/modelDecisions.txt
#    1 soilCatTbl: ROSETTA
#    2 vegeParTbl: MODIFIED_IGBP_MODIS_NOAH
#    3 soilStress: NoahType
#    4 stomResist: BallBerry
#    5 num_method: itertive
#    6 fDerivMeth: analytic
#    7 LAI_method: monTable
#    8 f_Richards: mixdform
#    9 groundwatr: bigBuckt
#   10 hc_profile: pow_prof
#   11 bcUpprTdyn: nrg_flux
#   12 bcLowrTdyn: zeroFlux
#   13 bcUpprSoiH: liq_flux
#   14 bcLowrSoiH: drainage
#   15 veg_traits: CM_QJRMS1988
#   16 rootProfil: powerLaw
#   17 canopyEmis: difTrans
#   18 snowIncept: stickySnow
#   19 windPrfile: logBelowCanopy
#   20 astability: louisinv
#   21 canopySrad: BeersLaw
#   22 alb_method: varDecay
#   23 compaction: anderson
#   24 snowLayers: CLM_2010
#   25 thCondSnow: jrdn1991
#   26 thCondSoil: funcSoilWet
#   27 spatial_gw: localColumn
#   28 subRouting: timeDlay
# startTime: iyyy, im, id, ih, imin = 2021 10  1  0  0
# finshTime: iyyy, im, id, ih, imin = 2023  9 30 23  0
# number of time steps =         731
#
# INFO: aspect not found in the input attribute file, continuing ...
#
# Skipping over LUTYPE = USGS
# Skipping over SLTYPE = STAS
# Skipping over SLTYPE = STAS-RUC
#  WARNING: routingRunoffFuture is not in the initial conditions file ... using zeros
#  Created output file: /storage/dlhogan/summa_modeling_data/domain_EastRiver/simulations/run1/SUMMA/run1_g1-1_G1-1_timestep.nc
# 2021 10  2  0  0
# 2021 10  3  0  0
# 2021 10  4  0  0
# 2021 10  5  0  0
# 2021 10  6  0  0
# 2021 10  7  0  0
# 2021 10  8  0  0
# 2021 10  9  0  0
# 2021 10 10  0  0
# 2021 10 11  0  0
# 2021 10 12  0  0
# 2021 10 13  0  0
# 2021 10 14  0  0
# 2021 10 15  0  0
# 2021 10 16  0  0
# 2021 10 17  0  0
# 2021 10 18  0  0
# 2021 10 19  0  0
# 2021 10 20  0  0
# 2021 10 21  0  0
# 2021 10 22  0  0
# 2021 10 23  0  0
# 2021 10 24  0  0
# 2021 10 25  0  0
# 2021 10 26  0  0
# 2021 10 27  0  0
# 2021 10 28  0  0
# 2021 10 29  0  0
# 2021 10 30  0  0
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 730, hru: 3)
# Coordinates:
#   * time       (time) datetime64[ns] 2021-10-01 2021-10-02 ... 2023-09-30
#   * hru        (hru) int64 0 1 2
# Data variables:
#     latitude   (hru) float64 ...
#     longitude  (hru) float64 ...
#     hruId      (hru) float64 ...
#     airpres    (time, hru) float64 ...
#     LWRadAtm   (time, hru) float64 ...
#     SWRadAtm   (time, hru) float64 ...
#     pptrate    (time, hru) float64 ...
#     airtemp    (time, hru) float64 ...
#     spechum    (time, hru) float64 ...
#     windspd    (time, hru) float64 ...
#     data_step  float64 ...
# Attributes:
#     Conventions:    CF-1.6
#     Author:         The data were written by Daniel L. Hogan
#     License:        None; Originla license: No license from original file is ...
#     History:        Created Wed Feb 12 13:33:23 2025by EASYMORE nc_remapper; ...
#     easymore_hash:  206c9e9d2c73d82b8b10ccf22b0b6804d6ffe5ec065955c33b6110722...
#     Source:         Remapped by EASYMORE nc_remapper from original file: /sto...

# %%
run1 = xr.open_dataset("/storage/dlhogan/summa_modeling_data/domain_EastRiver/simulations/run1/SUMMA/run1_g1-1_G1-1_timestep.nc")

run1['scalarTotalRunoff'].where(run1['scalarTotalRunoff']<1e-5).sum(dim='hru').plot()

# %% [markdown]
# As with the Simulation and Ensemble objects we can simply call .run() to start the simulations running. If you are running this tutorial interactively, this may take a moment because of the limited compute capacity of the binder instance. We have included the %%time magic to time how long this cell takes to run locally. You might expect this to take up to roughly two times the amount of time on the binder instance than is reported in the documentation at pysumma.readthedocs.io. As with the Ensemble we can use the .summary() method once the runs are complete to ensure that they all exit with status Success.

# %% [markdown]
# ### Basic Visuaklization
#
# Once we have run a successful simulation you might note that the gru dimension doesn’t contain any geometry data on which we can actually draw our output. To do that we will use the associated shapefile, loaded in via GeoPandas, and plot the mean surface temperature via the psp.spatial functionality. For more information on the spatial plotting capabilities see the plotting page in the documentation. Here we plot the traces of the input precipitation rate and total soil moisture timeseries for each of the HRU as well as a spatial plot showing the mean soil moisture over the simulation period.

# %%
shapefile = './tutorial/data/yakima/shapefile/yakima.shp'
gdf = gpd.GeoDataFrame.from_file(shapefile)

fig = plt.figure(figsize=(12, 6))
gs = fig.add_gridspec(2, 2)

ax1 = fig.add_subplot(gs[0, 0], )
yakima_ds['scalarTotalRunoff'].plot.line(x='time', ax=ax1, add_legend=False, color='dimgrey', alpha=0.1)
ax1.set_xlabel('')
ax1.set_xticks([])
ax1.set_ylabel('Precipitation rate ($kg / m^2 s$)')

ax2 = fig.add_subplot(gs[1, 0], )
yakima_ds['averageRoutedRunoff'].plot.line(x='time', ax=ax2, add_legend=False, color='dimgrey', alpha=0.1)
ax2.set_ylabel('Total liquid water in\n the soil column ($kg/m^2$)')
ax2.set_xlabel('')

ax3 = fig.add_subplot(gs[:, 1], projection=ccrs.Mercator())
psp.spatial(yakima_ds['averageRoutedRunoff'].sum(dim='time'), gdf, ax=ax3)
# Out:
# /home/dlhogan/miniforge3/envs/pysumma/lib/python3.9/site-packages/pysumma/plotting/spatial.py:73: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   patches = gen_patches(data_array, geodf_crs, robust)
# /home/dlhogan/miniforge3/envs/pysumma/lib/python3.9/site-packages/pysumma/plotting/spatial.py:19: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for sub in shp:
# <GeoAxes: >

# %%
forcing_ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 744, hru: 285)
# Coordinates:
#   * time       (time) datetime64[ns] 2010-06-01 ... 2010-07-01T23:00:00
#   * hru        (hru) int32 17006965 17006967 17006969 ... 17009662 17009664
# Data variables:
#     data_step  (time) timedelta64[ns] ...
#     hruId      (hru) int32 ...
#     pptrate    (time, hru) float32 ...
#     airtemp    (time, hru) float32 ...
#     windspd    (time, hru) float32 ...
#     spechum    (time, hru) float32 ...
#     airpres    (time, hru) float32 ...
#     LWRadAtm   (time, hru) float32 ...
#     SWRadAtm   (time, hru) float32 ...
# Attributes:
#     NCO:                       "4.6.1-alpha01"
#     nco_openmp_thread_number:  1

# %%
local_attributes = xr.open_dataset('./tutorial/data/yakima/params/parameter_trial.nc')
local_attributes.to_pandas()
# Out:
#        hruIndex  frozenPrecipMultip  theta_mp  theta_sat  theta_res  \
# hru
# 0    17006965.0                 1.0       0.3       0.55      0.139
# 1    17006967.0                 1.0       0.3       0.55      0.139
# 2    17006969.0                 1.0       0.3       0.55      0.139
# 3    17006970.0                 1.0       0.3       0.55      0.139
# 4    17006971.0                 1.0       0.3       0.55      0.139
# ..          ...                 ...       ...        ...        ...
# 280  17009596.0                 1.0       0.3       0.55      0.139
# 281  17009603.0                 1.0       0.3       0.55      0.139
# 282  17009604.0                 1.0       0.3       0.55      0.139
# 283  17009662.0                 1.0       0.3       0.55      0.139
# 284  17009664.0                 1.0       0.3       0.55      0.139
#
#      vGn_alpha  vGn_n  f_impede    k_soil  k_macropore  critSoilWilting  \
# hru
# 0         -0.5    1.3       2.0  0.000005         0.01             0.15
# 1         -0.5    1.3       2.0  0.000005         0.01             0.15
# 2         -0.5    1.3       2.0  0.000012         0.01             0.15
# 3         -0.5    1.3       2.0  0.000010         0.01             0.15
# 4         -0.5    1.3       2.0  0.000008         0.01             0.15
# ..         ...    ...       ...       ...          ...              ...
# 280       -0.5    1.3       2.0  0.000010         0.01             0.15
# 281       -0.5    1.3       2.0  0.000012         0.01             0.15
# 282       -0.5    1.3       2.0  0.000011         0.01             0.15
# 283       -0.5    1.3       2.0  0.000014         0.01             0.15
# 284       -0.5    1.3       2.0  0.000014         0.01             0.15
#
#      critSoilTranspire  winterSAI  summerLAI  heightCanopyTop  \
# hru
# 0                  0.2        0.4       2.08             20.0
# 1                  0.2        0.4       2.06             20.0
# 2                  0.2        0.3       0.65              0.5
# 3                  0.2        0.3       0.67              0.5
# 4                  0.2        0.3       0.63              0.5
# ..                 ...        ...        ...              ...
# 280                0.2        0.4       1.04             20.0
# 281                0.2        0.4       2.55             20.0
# 282                0.2        0.4       2.55             20.0
# 283                0.2        0.4       1.11             20.0
# 284                0.2        0.4       1.16             20.0
#
#      heightCanopyBottom  rootingDepth  rootDistExp
# hru
# 0                  8.50           2.0          1.0
# 1                  8.50           2.0          1.0
# 2                  0.05           2.0          1.0
# 3                  0.05           2.0          1.0
# 4                  0.05           2.0          1.0
# ..                  ...           ...          ...
# 280                8.50           2.0          1.0
# 281                8.50           2.0          1.0
# 282                8.50           2.0          1.0
# 283                8.50           2.0          1.0
# 284                8.50           2.0          1.0
#
# [285 rows x 18 columns]

# %% [markdown]
# ## Further configuration, and more advanced parallelism
#
# The Yakima River Basin given as an example here is a relatively small simulation of about 300 HRU for a month, but the parallelism approach built into the Distributed object can generally scale to many cores. Under the hood we rely on the `dask library <https://dask.org/>`__ to manage the scheduling of the parallel runs of both the Ensemble and Distributed objects. While we won’t actually run any simulations with these configurations, we show the code as a reference.

# %%
from dask.distributed import Client
from dask.distributed import LocalCluster
# from dask_jobqueue import SLURMCluster

# %%
from dask.distributed import Client

# %%
# Local example
N_WORKERS = 16 # A big machine might have 16 processors
local_cluster = LocalCluster(n_workers=N_WORKERS, threads_per_worker=1) # Each SUMMA simulation runs as a single-threaded process by default
local_example = Client(local_cluster) # This connects the compute cluster to the process running in this notebook

# Print the dashboard link
print(local_example.dashboard_link)
yakima_local = ps.Distributed(summa_exe, file_manager, client=local_example)
# Out:
# /home/dlhogan/miniforge3/envs/pysumma/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39139 instead
#   warnings.warn(
# http://127.0.0.1:39139/status

# %%
# %%time
yakima_local.run()
print(yakima_local.summary())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/miniforge3/envs/pysumma/lib/python3.9/site-packages/pysumma/distributed.py:159, in Distributed.run(self, run_option, prerun_cmds, monitor)
#     157 self.start(run_option, prerun_cmds)
#     158 if monitor:
# --> 159     return self.monitor()
#     160 else:
#     161     return True
#
# File ~/miniforge3/envs/pysumma/lib/python3.9/site-packages/pysumma/distributed.py:167, in Distributed.monitor(self)
#     163 def monitor(self):
#     164     """
#     165     Halt computation until submitted simulations are complete
#     166     """
# --> 167     simulations = self._client.gather(self.submissions)
#     168     for s in simulations:
#     169         self.simulations[s.run_suffix] = s
#
# File ~/miniforge3/envs/pysumma/lib/python3.9/site-packages/distributed/client.py:2305, in Client.gather(self, futures, errors, direct, asynchronous)
#    2303 else:
#    2304     local_worker = None
# -> 2305 return self.sync(
#    2306     self._gather,
#    2307     futures,
#    2308     errors=errors,
#    2309     direct=direct,
#    2310     local_worker=local_worker,
#    2311     asynchronous=asynchronous,
#    2312 )
#
# File ~/miniforge3/envs/pysumma/lib/python3.9/site-packages/distributed/utils.py:338, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     336     return future
#     337 else:
# --> 338     return sync(
#     339         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     340     )
#
# File ~/miniforge3/envs/pysumma/lib/python3.9/site-packages/distributed/utils.py:401, in sync(loop, func, callback_timeout, *args, **kwargs)
#     399 else:
#     400     while not e.is_set():
# --> 401         wait(10)
#     403 if error:
#     404     typ, exc, tb = error
#
# File ~/miniforge3/envs/pysumma/lib/python3.9/site-packages/distributed/utils.py:390, in sync.<locals>.wait(timeout)
#     388 def wait(timeout):
#     389     try:
# --> 390         return e.wait(timeout)
#     391     except KeyboardInterrupt:
#     392         loop.add_callback(cancel)
#
# File ~/miniforge3/envs/pysumma/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File ~/miniforge3/envs/pysumma/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
